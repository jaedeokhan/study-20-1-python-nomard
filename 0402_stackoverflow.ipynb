# %%
from indeed import get_jobs as get_indeed_jobs
from stackoverflow import get_jobs as get_so_jobs
from save import save_to_file

so_jobs = get_so_jobs()
indeed_jobs = get_indeed_jobs()
jobs =  so_jobs + indeed_jobs
save_to_file(jobs)

# CSV = Comma Separated Value
# Out:
# Indeed scrappying page number 1
# Indeed scrappying page number 2

# %%
import csv 

def save_to_file(jobs):
    file = open("jobs.csv", mode="w", encodig='utf-8')
    print (file)
    return

# %%
import requests
from bs4 import BeautifulSoup

URL = f"https://stackoverflow.com/jobs?q=python&sort=i&pg="

def get_last_page():
    result = requests.get(URL)
    soup = BeautifulSoup(result.content, 'html.parser')
    pages = soup.find('div', {'class' : 's-pagination'}).find_all('a')
#     pages = soup.select('a.s-pagination--item span')
    pages = int(pages[-2].text) # get_text(strip=True) 로도 whitespace 제거가 가능
    return pages

def extract_job(html):
#     title = html.select_one('div.-grid--cell.fl1 h2 a')
    title = html.find('div', {'class' : 'grid--cell fl1'}).find('h2').find('a')['title']
    title = title.replace('-', '')
    # span 안에 span이 있는 구문이 존재하면 recursive=False로 접근하지 않게 하는 것도 가능하다.
    # python 의 unpacking value 기능이다.
    # span의 첫 번째 요소에는 company를 담고, span의 두 번째 요소에는 location을 담는다.
    company, location = html.find('div', {'class' : 'grid--cell fl1'}).find('h3').find_all('span', recursive=False)
    company = company.get_text(strip=True) # strip('-') 와 같이 replace와 같은 기능을 한다.
    location = location.get_text(strip=True).replace(',', '') # 맥에서 \n은 \r 일수도 있음
    job_id = html['data-result-id']
    return {'title' : title, 'company' : company, 'location' : location,
           'link' : f'https://stackoverflow.com/jobs/{job_id}'}

def extract_jobs(last_page):
    jobs = []
    for page in range(last_page):
        if page == 8:
            break
        print (f'scrappying page number {page + 1}')
        result = requests.get(f"{URL}{page + 1}") # page + 1
        soup = BeautifulSoup(result.content, 'html.parser')
        results = soup.find_all('div', {'class' : '-job'})
        for result in results:
            job = extract_job(result)
            jobs.append(job)
    return jobs

def get_jobs():
    last_page = get_last_page()
    jobs = extract_jobs(last_page)
    return jobs

get_jobs()
# Out:
# scrappying page number 1
# scrappying page number 2
# scrappying page number 3
# scrappying page number 4
# scrappying page number 5
# scrappying page number 6
# scrappying page number 7
# scrappying page number 8
# [{'title': 'Senior Database Engineer',
#   'company': 'TransferWise',
#   'location': 'London UK',
#   'link': 'https://stackoverflow.com/jobs/379652'},
#  {'title': 'Senior Solution Engineer (m/f/d)',
#   'company': 'Swarm64 AS Zweigstelle Hive',
#   'location': 'Berlin Germany',
#   'link': 'https://stackoverflow.com/jobs/293986'},
#  {'title': 'ITEntwickler | DevOpsProgrammierer (m/w/d) Python, JavaScript, Bash und Powershell',
#   'company': 'Paracelsus-Kliniken Deutschland GmbH & Co. KGaA',
#   'location': 'Osnabrück Germany',
#   'link': 'https://stackoverflow.com/jobs/371074'},
#  {'title': 'DevOps Engineer  Security',
#   'company': 'Stratifyd',
#   'location': 'Charlotte NC',
#   'link': 'https://stackoverflow.com/jobs/371114'},
#  {'title': 'Senior Software Engineer C++ for System Integration & CI (f/m/x)',
#   'company': 'BMW Group',
#   'location': 'München Deutschland',
#   'link': 'https://stackoverflow.com/jobs/333745'},
#  {'title': 'Lead Software Engineer (Java)',
#   'company': 'CIRC',
#   'location': 'Berlin Germany',
#   'link': 'https://stackoverflow.com/jobs/265419'},
#  {'title': 'Online Infrastructure Engineer/Site Reliability Engineer',
#   'company': 'Massive Entertainment - A Ubisoft Studio',
#   'location': 'Malmö Sweden',
#   'link': 'https://stackoverflow.com/jobs/312460'},
#  {'title': 'DevOps Engineer (m/w/d)',
#   'company': 'CIS Solutions GmbH',
#   'location': 'Ismaning Deutschland',
#   'link': 'https://stackoverflow.com/jobs/371069'},
#  {'title': 'CPU Performance Modelling Engineer',
#   'company': 'Imagination Technologies',
#   'location': 'Kings Langley UK',
#   'link': 'https://stackoverflow.com/jobs/379650'},
#  {'title': 'Site Reliability Engineering Manager',
#   'company': 'Apple',
#   'location': 'Cupertino CA',
#   'link': 'https://stackoverflow.com/jobs/364704'},
#  {'title': 'Sr. Technical Engineer',
#   'company': 'Solace',
#   'location': 'Ottawa ON Canada',
#   'link': 'https://stackoverflow.com/jobs/379648'},
#  {'title': 'Software Engineer',
#   'company': 'Watcha',
#   'location': 'Gangnam-daero South Korea',
#   'link': 'https://stackoverflow.com/jobs/379646'},
#  {'title': 'Data Engineer',
#   'company': 'Executive SolutionsviaExecutive Solutions',
#   'location': 'Abu Dhabi United Arab Emirates',
#   'link': 'https://stackoverflow.com/jobs/371056'},
#  {'title': 'Director, Technical Program Management  Infrastructure Product and Platforms',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379643'},
#  {'title': 'Manager, Software Engineering  Blockchain Group',
#   'company': 'Facebook',
#   'location': 'Tel Aviv-Yafo Israel',
#   'link': 'https://stackoverflow.com/jobs/273897'},
#  {'title': 'Partner Engineer',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379640'},
#  {'title': 'Cloud Infrastructure Engineer',
#   'company': 'Facebook',
#   'location': 'Boston MA',
#   'link': 'https://stackoverflow.com/jobs/379639'},
#  {'title': 'Cloud Engineer / SRE / DevOps',
#   'company': 'KI group GmbH',
#   'location': 'München Germany',
#   'link': 'https://stackoverflow.com/jobs/208050'},
#  {'title': 'Team Lead Engineering',
#   'company': 'MessageBird',
#   'location': 'Amsterdam Netherlands',
#   'link': 'https://stackoverflow.com/jobs/379637'},
#  {'title': 'Embedded Software Engineer C++',
#   'company': 'Sonova AG',
#   'location': 'Stäfa Schweiz',
#   'link': 'https://stackoverflow.com/jobs/273023'},
#  {'title': 'Data Engineer',
#   'company': 'TrinityRock Advisors',
#   'location': 'Boston MA',
#   'link': 'https://stackoverflow.com/jobs/346317'},
#  {'title': 'Backend Engineer  Python (m/f/d)',
#   'company': 'FINEWAY',
#   'location': 'Munich Germany',
#   'link': 'https://stackoverflow.com/jobs/333801'},
#  {'title': 'IT Class  Software Engineer',
#   'company': 'ING',
#   'location': 'Amsterdam Netherlands',
#   'link': 'https://stackoverflow.com/jobs/379633'},
#  {'title': 'FULLSTACK PYTHON (DJANGO) DEVELOPER',
#   'company': 'Scalable Path',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/379632'},
#  {'title': 'Infrastructure Solutions Engineer',
#   'company': 'JP Morgan Chase',
#   'location': 'Wilmington DE',
#   'link': 'https://stackoverflow.com/jobs/379631'},
#  {'title': 'Python Developer',
#   'company': 'Zaaksysteem.nl',
#   'location': 'Amsterdam Netherlands',
#   'link': 'https://stackoverflow.com/jobs/333770'},
#  {'title': 'IT Dev Engineer  Finance and Risk domain',
#   'company': 'ING',
#   'location': 'Amsterdam Netherlands',
#   'link': 'https://stackoverflow.com/jobs/371344'},
#  {'title': 'Senior QA Automation Engineer Storage Team at 1FA Broadgate London',
#   'company': 'Mimecast',
#   'location': 'London UK',
#   'link': 'https://stackoverflow.com/jobs/273012'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'Bloomreach',
#   'location': 'Amsterdam Netherlands',
#   'link': 'https://stackoverflow.com/jobs/371047'},
#  {'title': 'Data Engineer (f/m) 80100%',
#   'company': 'Tamedia',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/371040'},
#  {'title': 'Softwareentwickler (m/w/d) mit dem Schwerpunkt Videoverteilung',
#   'company': 'Rheinmetall Group',
#   'location': 'Bremen Germany',
#   'link': 'https://stackoverflow.com/jobs/333764'},
#  {'title': 'AWS AI Devices  Quality Assurance Engineer',
#   'company': 'Amazon',
#   'location': 'East Palo Alto CA',
#   'link': 'https://stackoverflow.com/jobs/379615'},
#  {'title': 'Team Lead Business Intelligence',
#   'company': 'Coolblue',
#   'location': 'Rotterdam Netherlands',
#   'link': 'https://stackoverflow.com/jobs/378017'},
#  {'title': 'Software Test Infrastructure Engineer',
#   'company': 'Zurich Instruments AG',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/338159'},
#  {'title': 'Senior Software Test Engineer',
#   'company': 'Zurich Instruments AG',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/338167'},
#  {'title': 'DevOps Engineer',
#   'company': 'Zurich Instruments AG',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/338182'},
#  {'title': 'Senior Java Engineer',
#   'company': "Sainsbury's DTD (Digital, Tech, Data)",
#   'location': 'Manchester UK',
#   'link': 'https://stackoverflow.com/jobs/333748'},
#  {'title': 'Senior Support Engineer',
#   'company': 'ThinkParQ GmbH',
#   'location': 'Kaiserslautern Germany',
#   'link': 'https://stackoverflow.com/jobs/333735'},
#  {'title': 'Software Engineer (f/m/d) – C++ Render Engine Integration',
#   'company': 'Dassault Systemes Deutschland GmbH',
#   'location': 'Munich Germany',
#   'link': 'https://stackoverflow.com/jobs/371032'},
#  {'title': 'Senior Backend Python Developer (m/f/d)',
#   'company': 'sonnen GmbH',
#   'location': 'Berlin Deutschland',
#   'link': 'https://stackoverflow.com/jobs/333733'},
#  {'title': 'Lead Site Reliability Engineer',
#   'company': 'Anapaya Systems',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/313028'},
#  {'title': 'Devops/Automation Engineer  junior/midlevel',
#   'company': 'Anapaya Systems',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/350306'},
#  {'title': 'Full Stack Developer, ready to do great work and learn with the experts?',
#   'company': 'Agile Digital',
#   'location': 'Canberra Australia',
#   'link': 'https://stackoverflow.com/jobs/46759'},
#  {'title': 'Full Stack Developers',
#   'company': 'CogniSun Infotech',
#   'location': 'Ahmedabad India',
#   'link': 'https://stackoverflow.com/jobs/370986'},
#  {'title': 'Lead iOS, Android, Web Developers, System Analysts and Web Designers',
#   'company': 'Bharja Technologies',
#   'location': 'Ahmedabad India',
#   'link': 'https://stackoverflow.com/jobs/370985'},
#  {'title': 'Technology  Trainee  2020 (AI, Android, Backend & More...)',
#   'company': 'O2h',
#   'location': 'Ahmedabad India',
#   'link': 'https://stackoverflow.com/jobs/345932'},
#  {'title': 'Technology  Trainee  2020 (AI, Android, Backend & More...)',
#   'company': 'o2h Group',
#   'location': 'Ahmedabad India',
#   'link': 'https://stackoverflow.com/jobs/350188'},
#  {'title': 'データサイエンティスト / インターネット/Webサービス・ASP',
#   'company': '株式会社 aiforce solutions',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/312264'},
#  {'title': 'Software Engineer (Web Technologies)',
#   'company': 'AdElement',
#   'location': 'Pune India',
#   'link': 'https://stackoverflow.com/jobs/346251'},
#  {'title': 'Software Q/A Engineer – SQE',
#   'company': 'Anju Software',
#   'location': 'Pune India',
#   'link': 'https://stackoverflow.com/jobs/346227'},
#  {'title': 'SOFTWARE TESTING ENGINEER',
#   'company': 'VM3 Tech Solution LLP',
#   'location': 'Pune India',
#   'link': 'https://stackoverflow.com/jobs/346226'},
#  {'title': 'Senior Software Engineer',
#   'company': 'MAQ Software',
#   'location': 'Hyderabad India',
#   'link': 'https://stackoverflow.com/jobs/346161'},
#  {'title': 'Manager, Software Engineering, Data experiences',
#   'company': 'Facebook',
#   'location': 'Tel Aviv-Yafo Israel',
#   'link': 'https://stackoverflow.com/jobs/379602'},
#  {'title': 'Partner Engineer, AI',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379599'},
#  {'title': 'Software Engineer, Serverside',
#   'company': 'SmartNews',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/208334'},
#  {'title': 'Software Engineer, Data Platform',
#   'company': 'SmartNews',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/219294'},
#  {'title': 'Senior Software Engineer in Test  Mobile',
#   'company': 'Coupa',
#   'location': 'Pune India',
#   'link': 'https://stackoverflow.com/jobs/333609'},
#  {'title': 'Site Reliability Engineer (Data Platforms)',
#   'company': 'Autumn Compass',
#   'location': 'Sydney Australia',
#   'link': 'https://stackoverflow.com/jobs/379594'},
#  {'title': 'Quality Engineer',
#   'company': 'OR Technologies',
#   'location': 'Abbotsford Australia',
#   'link': 'https://stackoverflow.com/jobs/370910'},
#  {'title': 'ETL Engineer / Data Platform',
#   'company': 'LINE株式会社',
#   'location': 'Shinjuku City Japan',
#   'link': 'https://stackoverflow.com/jobs/310074'},
#  {'title': 'システム開発(Web・オープン系,汎用系)',
#   'company': 'パーソル パナソニック HRパートナーズ株式会社',
#   'location': 'Osaka Japan',
#   'link': 'https://stackoverflow.com/jobs/341906'},
#  {'title': '三軒茶屋 機械学習 早めにスタート!',
#   'company': 'フィック株式会社',
#   'location': 'Setagaya City Japan',
#   'link': 'https://stackoverflow.com/jobs/358563'},
#  {'title': 'Data Engineer / LINE広告',
#   'company': 'LINE株式会社',
#   'location': 'Shinjuku City Japan',
#   'link': 'https://stackoverflow.com/jobs/316542'},
#  {'title': 'Python, Php Developer',
#   'company': 'TIGI HR Solution Pvt. Ltd.',
#   'location': 'Ahmedabad India',
#   'link': 'https://stackoverflow.com/jobs/342833'},
#  {'title': 'Sales Executive',
#   'company': 'Prime Infoserv',
#   'location': 'Kolkata India',
#   'link': 'https://stackoverflow.com/jobs/379566'},
#  {'title': 'Sales Manager',
#   'company': 'Prime Infoserv',
#   'location': 'Kolkata India',
#   'link': 'https://stackoverflow.com/jobs/379558'},
#  {'title': 'Senior PHP Developer',
#   'company': 'ViaPocket Solutions',
#   'location': 'Serampore India',
#   'link': 'https://stackoverflow.com/jobs/379555'},
#  {'title': '.Net Developer',
#   'company': 'technosoft corporation',
#   'location': 'Bengaluru India',
#   'link': 'https://stackoverflow.com/jobs/322368'},
#  {'title': 'CTO室メンバー職',
#   'company': 'type転職エージェント',
#   'location': 'Chuo City Japan',
#   'link': 'https://stackoverflow.com/jobs/346131'},
#  {'title': '[DTS] TCS Interactive テクニカルマネージャー/テクニカルリード',
#   'company': '日本タタ・コンサルタンシー・サービシズ株式会社',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/346129'},
#  {'title': 'バックエンドエンジニア《Python・PHP 経験者大歓迎》',
#   'company': '株式会社エルテス',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/346124'},
#  {'title': 'Polyglot Software Engineers for next generation R+D Cyber Security Program',
#   'company': 'Hays plcviaHays plc',
#   'location': 'Sydney Australia',
#   'link': 'https://stackoverflow.com/jobs/170915'},
#  {'title': 'Junior Full Stack Software Engineer',
#   'company': 'Warner MusicviaHays plc',
#   'location': 'Haymarket Australia',
#   'link': 'https://stackoverflow.com/jobs/333490'},
#  {'title': 'Full Stack Web Developer',
#   'company': 'Art & Logic, Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/370918'},
#  {'title': 'SE',
#   'company': 'シルバーエッグ・テクノロジー株式会社',
#   'location': 'Suita Japan',
#   'link': 'https://stackoverflow.com/jobs/376138'},
#  {'title': 'フリーランス\u3000メーカー向けPMO対応\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/379522'},
#  {'title': 'プロジェクトマネージャー',
#   'company': '株式会社ビザスク',
#   'location': 'Meguro City Japan',
#   'link': 'https://stackoverflow.com/jobs/375898'},
#  {'title': '【テクニカルアーティスト(AAAタイトル)】株式会社Cygames/経験者歓迎×高時給',
#   'company': '株式会社ヴィジョナリー',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379521'},
#  {'title': 'SE',
#   'company': 'SORABITO株式会社',
#   'location': 'Chuo City Japan',
#   'link': 'https://stackoverflow.com/jobs/379504'},
#  {'title': 'WEB系プログラマ(PHP / Python / Java) 第二新卒・中途',
#   'company': '株式会社ジャスウィル',
#   'location': 'Nagoya Japan',
#   'link': 'https://stackoverflow.com/jobs/348253'},
#  {'title': 'WEBプログラマ(PHP/Python/Java)伏見駅5分',
#   'company': '株式会社ジャスウィル',
#   'location': 'Nagoya Japan',
#   'link': 'https://stackoverflow.com/jobs/379486'},
#  {'title': 'システム開発(オープン・WEB・モバイル)',
#   'company': '大化物流開発合同会社',
#   'location': 'Osaka Japan',
#   'link': 'https://stackoverflow.com/jobs/333522'},
#  {'title': '【広告プロダクト開発エンジニア】DMM.com/<アニメ・ゲーム好き歓迎×業界未経験可>',
#   'company': '株式会社ヴィジョナリー',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379464'},
#  {'title': 'セキュリティ監視システム開発',
#   'company': '株式会社エーティーエス',
#   'location': 'Osaka Japan',
#   'link': 'https://stackoverflow.com/jobs/379460'},
#  {'title': 'SE',
#   'company': '株式会社パネイル',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/330964'},
#  {'title': 'プログラマー',
#   'company': '株式会社キャリアブロックス',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/379447'},
#  {'title': '週4日で在宅OKのシステム開発会社のSE',
#   'company': '株式会社プライムスタイル',
#   'location': 'Bunkyo City Japan',
#   'link': 'https://stackoverflow.com/jobs/379445'},
#  {'title': 'フリーランス\u3000テスト支援業務\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Shinjuku City Japan',
#   'link': 'https://stackoverflow.com/jobs/379440'},
#  {'title': '【サーバサイドエンジニア(使用言語:Python, Ruby, Java)】株式会社AbemaTV<渋谷駅徒歩9分>',
#   'company': '株式会社ヴィジョナリー',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379438'},
#  {'title': 'クラウドエンジニア / Webマーケティング・ネット広告',
#   'company': '株式会社 ビデオリサーチ',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/354517'},
#  {'title': 'Webアプリケーションエンジニア【東京勤務】/インターネット/Webサービス・ASP',
#   'company': '株式会社 はてな',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379434'},
#  {'title': 'サービス開発エンジニア/インターネット/Webサービス・ASP',
#   'company': '株式会社 ハウテレビジョン',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379433'},
#  {'title': '【東京】クラウドサービス開発エンジニア(バックエンドエンジニア) / インターネット/Webサービス・ASP',
#   'company': '株式会社 ブロードリーフ',
#   'location': 'Shinagawa City Japan',
#   'link': 'https://stackoverflow.com/jobs/379432'},
#  {'title': 'プロジェクトエンジニア/フロントエンジニア / インターネット/Webサービス・ASP',
#   'company': 'CCCフロンティア 株式会社',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379430'},
#  {'title': 'ITエンジニア / インターネット/Webサービス・ASP',
#   'company': '株式会社 コントロールテクノロジー',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/338317'},
#  {'title': '開発エンジニア(サーバー) / システムインテグレータ・ソフトハウス',
#   'company': '株式会社 AXSEED',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379429'},
#  {'title': 'エンジニアマネージャー / インターネット/Webサービス・ASP',
#   'company': 'Wantedly 株式会社',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/310187'},
#  {'title': 'インフラエンジニア (分析基盤/プロダクト開発)',
#   'company': 'Supershipグループ',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379427'},
#  {'title': '新卒採用 エンジニア・企画営業',
#   'company': '株式会社エムフロ',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379424'},
#  {'title': 'webシステムエンジニア',
#   'company': 'type転職エージェント',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379423'},
#  {'title': 'サーバーエンジニア / システムインテグレータ・ソフトハウス',
#   'company': '株式会社 NTTPCコミュニケーションズ',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/318326'},
#  {'title': 'バックエンドエンジニア / 広告・デザイン・イベント',
#   'company': '株式会社 ギークピクチュアズ',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379421'},
#  {'title': 'フリーランス\u3000金融業向けシステム開発エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379418'},
#  {'title': 'フロントエンジニア / インターネット/Webサービス・ASP',
#   'company': 'SELF 株式会社',
#   'location': 'Shinjuku City Japan',
#   'link': 'https://stackoverflow.com/jobs/379417'},
#  {'title': 'プロジェクトマネージャー / システムインテグレータ・ソフトハウス',
#   'company': '株式会社 システムシェアード',
#   'location': 'Taito City Japan',
#   'link': 'https://stackoverflow.com/jobs/327691'},
#  {'title': 'システムエンジニア',
#   'company': '株式会社ヴァンガードテクノロジー(勤務地:渋谷区エリア)',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379413'},
#  {'title': 'Webアプリケーションエンジニア',
#   'company': 'type転職エージェント',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379412'},
#  {'title': 'サーバーサイドエンジニア / 新規サービス・NAVERまとめ',
#   'company': 'LINE株式会社',
#   'location': 'Shinjuku City Japan',
#   'link': 'https://stackoverflow.com/jobs/309994'},
#  {'title': 'WEBエンジニア',
#   'company': '東京アドメディカ',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379410'},
#  {'title': 'システムエンジニア/プログラマー / 物流・運送・倉庫・梱包',
#   'company': 'ウィルポート 株式会社',
#   'location': 'Chuo City Japan',
#   'link': 'https://stackoverflow.com/jobs/316931'},
#  {'title': 'フリーランス\u3000NW設計・構築、NW運用\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': '千代田区 Japan',
#   'link': 'https://stackoverflow.com/jobs/379406'},
#  {'title': 'サーバーサイドエンジニア',
#   'company': '株式会社リブセンス',
#   'location': 'Shinagawa City Japan',
#   'link': 'https://stackoverflow.com/jobs/379405'},
#  {'title': 'システム開発エンジニア',
#   'company': '株式会社メルメクス',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/331545'},
#  {'title': 'Webエンジニア',
#   'company': '株式会社メンバーズ-メンバーズエッジ・カンパニー',
#   'location': 'Chuo City Japan',
#   'link': 'https://stackoverflow.com/jobs/318433'},
#  {'title': '[社]未経験歓迎UnixCエンジニア/いきなり現場配属はありません',
#   'company': 'セブンシーズ株式会社',
#   'location': 'Shinjuku City Japan',
#   'link': 'https://stackoverflow.com/jobs/379401'},
#  {'title': 'フリーランス\u3000ECサイト構築エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379399'},
#  {'title': 'オープン系/Web系/モバイル系エンジニア《女性内定多数》',
#   'company': '株式会社ファーンリッジ・ジャパン',
#   'location': 'Shibuya City Japan',
#   'link': 'https://stackoverflow.com/jobs/379397'},
#  {'title': 'ネットワークアプリケーションエンジニア',
#   'company': '任天堂株式会社',
#   'location': 'Taito City Japan',
#   'link': 'https://stackoverflow.com/jobs/335785'},
#  {'title': '【AIをやってみたい!】 AI開発エンジニア/インターネット/Webサービス・ASP',
#   'company': '株式会社 GRI',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379392'},
#  {'title': 'サーバーサイドエンジニア',
#   'company': '株式会社アイリッジ',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379390'},
#  {'title': 'プロジェクトマネージャー/プロダクトマネージャー',
#   'company': 'type転職エージェント',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/379386'},
#  {'title': 'フリーランス\u3000データ分析エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/379385'},
#  {'title': 'コンテンツプラットフォームエンジニア',
#   'company': '株式会社Gunosy',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/375681'},
#  {'title': '社内SE・システム管理',
#   'company': '株式会社キュービック',
#   'location': 'Shinjuku City Japan',
#   'link': 'https://stackoverflow.com/jobs/331107'},
#  {'title': 'プログラマー',
#   'company': '株式会社キャリアブロックス',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/379381'},
#  {'title': 'Senior C++ Engineer',
#   'company': 'Soul Machines Limited',
#   'location': 'Auckland New Zealand',
#   'link': 'https://stackoverflow.com/jobs/365641'},
#  {'title': '【フルスタックエンジニア(大規模Webサービス)】株式会社ビットエー<五反田駅徒歩5分×残業少>',
#   'company': '株式会社ヴィジョナリー',
#   'location': 'Shinagawa City Japan',
#   'link': 'https://stackoverflow.com/jobs/379379'},
#  {'title': '戦略コンサルタント',
#   'company': 'Luce',
#   'location': 'Chiyoda City Japan',
#   'link': 'https://stackoverflow.com/jobs/379378'},
#  {'title': '週4・時短もOK 総月間PV2000万 残業少なめ GパンOK/Python開発',
#   'company': '株式会社キャリアデザインITパートナーズ',
#   'location': 'Minato City Japan',
#   'link': 'https://stackoverflow.com/jobs/379377'},
#  {'title': 'システムエンジニア(週5日)/無資格可',
#   'company': '株式会社 分析屋',
#   'location': 'Fujisawa Japan',
#   'link': 'https://stackoverflow.com/jobs/379376'},
#  {'title': 'フリーランス\u3000アプリケーション開発エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Kawasaki Japan',
#   'link': 'https://stackoverflow.com/jobs/379372'},
#  {'title': 'フリーランス\u3000インフラ系PM\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Kawasaki Japan',
#   'link': 'https://stackoverflow.com/jobs/379371'},
#  {'title': 'フリーランス\u3000機能追加エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Kawasaki Japan',
#   'link': 'https://stackoverflow.com/jobs/379370'},
#  {'title': 'フリーランス\u3000流通業向けキッティング作業\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Chiba Japan',
#   'link': 'https://stackoverflow.com/jobs/379366'},
#  {'title': 'フリーランス\u3000システム構築エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Chiba Japan',
#   'link': 'https://stackoverflow.com/jobs/379365'},
#  {'title': '【福岡】インフラエンジニア(PL,PM)/インターネット/Webサービス・ASP',
#   'company': '株式会社 ブロードリーフ',
#   'location': 'Fukuoka Japan',
#   'link': 'https://stackoverflow.com/jobs/379363'},
#  {'title': '【福岡】クラウドサービスの開発エンジニア(リーダー)/インターネット/Webサービス・ASP',
#   'company': '株式会社 ブロードリーフ',
#   'location': 'Fukuoka Japan',
#   'link': 'https://stackoverflow.com/jobs/379362'},
#  {'title': 'ITコンサルタント',
#   'company': '株式会社TechJIN',
#   'location': 'Fukuoka Japan',
#   'link': 'https://stackoverflow.com/jobs/379361'},
#  {'title': 'フリーランス\u3000メーカー向けAPI基盤構築エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Yokohama Japan',
#   'link': 'https://stackoverflow.com/jobs/379360'},
#  {'title': 'フリーランス\u3000メーカー向けABAP開発対応\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Yokohama Japan',
#   'link': 'https://stackoverflow.com/jobs/379359'},
#  {'title': 'フリーランス\u3000金融業向けシステム構築エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Yokohama Japan',
#   'link': 'https://stackoverflow.com/jobs/379358'},
#  {'title': '水稲圃場農業情報AgriLook基本設計 (システム開発メーカー) Linux',
#   'company': '株式会社スタッフサービス',
#   'location': 'Tsukuba Japan',
#   'link': 'https://stackoverflow.com/jobs/379357'},
#  {'title': 'フリーランス\u3000仮想基盤構築エンジニア\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Wako Japan',
#   'link': 'https://stackoverflow.com/jobs/379355'},
#  {'title': 'フリーランス\u3000メーカー向けPMO対応\u300030代・40代活躍中',
#   'company': '株式会社ビーブレイクシステムズ',
#   'location': 'Okegawa Japan',
#   'link': 'https://stackoverflow.com/jobs/379354'},
#  {'title': 'SE・PG(オープン系)/大手メーカー光ディスクアーカイブシステムの制御ソフト開発',
#   'company': 'パーソル パナソニック HRパートナーズ株式会社\u3000テクニカル事業本部',
#   'location': '門真市 Japan',
#   'link': 'https://stackoverflow.com/jobs/376390'},
#  {'title': 'Technical Lead',
#   'company': 'Jane Technologies, Inc.',
#   'location': 'Santa Cruz CA',
#   'link': 'https://stackoverflow.com/jobs/377599'},
#  {'title': 'Data Platform Engineer',
#   'company': 'Geomagical Labs',
#   'location': 'Mountain View CA',
#   'link': 'https://stackoverflow.com/jobs/379349'},
#  {'title': 'Software Developers and Operations Personnel for Healthcare Platform',
#   'company': 'CareEvolution',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/379348'},
#  {'title': 'Senior Software Engineer, Fullstack',
#   'company': 'valora digital.',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/302271'},
#  {'title': 'Internal Solutions Engineer, Global Marketing Solutions',
#   'company': 'Facebook',
#   'location': 'Austin TX',
#   'link': 'https://stackoverflow.com/jobs/379347'},
#  {'title': 'Software Engineer  Java/Angular',
#   'company': 'JP Morgan Chase',
#   'location': 'Glasgow UK',
#   'link': 'https://stackoverflow.com/jobs/379305'},
#  {'title': 'Network Engineer',
#   'company': 'Facebook',
#   'location': 'Dublin Ireland',
#   'link': 'https://stackoverflow.com/jobs/379346'},
#  {'title': 'Data Center Network Engineer',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379342'},
#  {'title': 'Wireless Systems Engineer',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379341'},
#  {'title': 'Enterprise Engineer, University Graduate  Enterprise Products',
#   'company': 'Facebook',
#   'location': 'Dublin Ireland',
#   'link': 'https://stackoverflow.com/jobs/379340'},
#  {'title': 'Internal Solutions Engineer',
#   'company': 'Facebook',
#   'location': 'Hyderabad India',
#   'link': 'https://stackoverflow.com/jobs/379339'},
#  {'title': 'Partner Engineer, Shared Infrastructure, SubSahara Africa',
#   'company': 'Facebook',
#   'location': 'Johannesburg South Africa',
#   'link': 'https://stackoverflow.com/jobs/379338'},
#  {'title': 'CAD & Methodology Engineer',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379336'},
#  {'title': 'Data Engineer, Analytics',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379335'},
#  {'title': 'Production Engineer, Discover Production Engineering',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379329'},
#  {'title': 'Software Engineering Apprenticeship',
#   'company': 'Facebook',
#   'location': 'London UK',
#   'link': 'https://stackoverflow.com/jobs/379323'},
#  {'title': 'Algorithm Engineer, Connectivity',
#   'company': 'Facebook',
#   'location': 'Los Angeles CA',
#   'link': 'https://stackoverflow.com/jobs/379321'},
#  {'title': 'Data Engineering Manager, Partnerships Central Systems, Data and Tools',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/379318'},
#  {'title': 'Senior Site Reliability Engineer, Platform  Cisco Meraki',
#   'company': 'Source Coders Inc',
#   'location': 'San Francisco CA',
#   'link': 'https://stackoverflow.com/jobs/379312'},
#  {'title': 'Software Development Engineer in Test (SDET)  REMOTE',
#   'company': 'Thermopylae Sciences and Technology',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/379311'},
#  {'title': 'Distributed Systems Engineer',
#   'company': 'Aerial Applications',
#   'location': 'Washington DC',
#   'link': 'https://stackoverflow.com/jobs/370904'},
#  {'title': 'Head of Engineering',
#   'company': 'valora digital.',
#   'location': 'Zürich Switzerland',
#   'link': 'https://stackoverflow.com/jobs/301871'},
#  {'title': 'Senior Software Developer',
#   'company': 'BPI, Inc',
#   'location': 'Vancouver BC Canada',
#   'link': 'https://stackoverflow.com/jobs/302265'},
#  {'title': 'Python Back End Engineer',
#   'company': 'Loadsmart',
#   'location': 'Florianópolis Brazil',
#   'link': 'https://stackoverflow.com/jobs/370893'},
#  {'title': 'Senior Application Security Engineer',
#   'company': 'Wikimedia Foundation, Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/370892'},
#  {'title': 'Software Engineering  Java',
#   'company': 'JP Morgan Chase',
#   'location': 'Tampa FL',
#   'link': 'https://stackoverflow.com/jobs/379309'},
#  {'title': 'Senior Backend Engineer (Ruby, Python)',
#   'company': 'Transfix',
#   'location': 'New York NY',
#   'link': 'https://stackoverflow.com/jobs/284193'},
#  {'title': 'Java Software Engineer',
#   'company': 'JP Morgan Chase',
#   'location': 'Columbus OH',
#   'link': 'https://stackoverflow.com/jobs/379308'},
#  {'title': 'Full Stack .NET Software Engineer',
#   'company': 'JP Morgan Chase',
#   'location': 'Houston TX',
#   'link': 'https://stackoverflow.com/jobs/379307'},
#  {'title': 'Software Engineer  Java/Angular',
#   'company': 'JP Morgan Chase',
#   'location': 'Glasgow UK',
#   'link': 'https://stackoverflow.com/jobs/379306'},
#  {'title': 'Machine Learning Engineer',
#   'company': 'Builder',
#   'location': 'Gurugram India',
#   'link': 'https://stackoverflow.com/jobs/379294'},
#  {'title': 'Software Engineer  Java/Angular',
#   'company': 'JP Morgan Chase',
#   'location': 'Glasgow UK',
#   'link': 'https://stackoverflow.com/jobs/379304'},
#  {'title': 'Engineering Manager',
#   'company': 'Force Therapeutics',
#   'location': 'New York NY',
#   'link': 'https://stackoverflow.com/jobs/260145'},
#  {'title': 'Production Engineer',
#   'company': 'Facebook',
#   'location': 'Seattle WA',
#   'link': 'https://stackoverflow.com/jobs/353874'},
#  {'title': 'Lead Site Reliability Engineer',
#   'company': 'JP Morgan Chase',
#   'location': 'Houston TX',
#   'link': 'https://stackoverflow.com/jobs/379303'},
#  {'title': 'Site Reliability Engineer',
#   'company': 'JP Morgan Chase',
#   'location': 'Houston TX',
#   'link': 'https://stackoverflow.com/jobs/379302'},
#  {'title': 'Sr Software Quality Engineer',
#   'company': 'idwall',
#   'location': 'São Paulo Brazil',
#   'link': 'https://stackoverflow.com/jobs/370887'},
#  {'title': 'Software Engineer (Machine Learning)',
#   'company': 'Unlearn.ai',
#   'location': 'San Francisco CA',
#   'link': 'https://stackoverflow.com/jobs/370885'},
#  {'title': 'Software Engineer (Data Science)',
#   'company': 'Unlearn.ai',
#   'location': 'San Francisco CA',
#   'link': 'https://stackoverflow.com/jobs/370884'},
#  {'title': 'Sr Data Engineering',
#   'company': 'idwall',
#   'location': 'São Paulo Brazil',
#   'link': 'https://stackoverflow.com/jobs/356319'},
#  {'title': 'Jr. Linux Systems Administrator',
#   'company': 'Clover Leaf Solutions, Inc.',
#   'location': 'Albuquerque NM',
#   'link': 'https://stackoverflow.com/jobs/339328'},
#  {'title': 'Data Scientist',
#   'company': 'LogRocket',
#   'location': 'Boston MA',
#   'link': 'https://stackoverflow.com/jobs/370880'},
#  {'title': 'Senior Network Engineer  Remote, Boston, New York, or San Francisco',
#   'company': 'Underline',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/370877'},
#  {'title': 'Senior Security Researcher, Applications  100% Remote Colombia South America',
#   'company': 'Sonatype',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/370875'},
#  {'title': 'Senior Security Researcher, Applications  100% Remote Canada',
#   'company': 'Sonatype',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/208728'},
#  {'title': 'Software Engineer, Full Stack',
#   'company': 'Forward',
#   'location': 'San Francisco CA',
#   'link': 'https://stackoverflow.com/jobs/336573'},
#  {'title': 'Software Engineer, Backend Infrastructure',
#   'company': 'Forward',
#   'location': 'San Francisco CA',
#   'link': 'https://stackoverflow.com/jobs/345270'},
#  {'title': 'BackEnd Engineer',
#   'company': 'Gorgias',
#   'location': 'Paris France',
#   'link': 'https://stackoverflow.com/jobs/371615'},
#  {'title': 'FullStack Python Engineer',
#   'company': 'Gorgias',
#   'location': 'Paris France',
#   'link': 'https://stackoverflow.com/jobs/333474'},
#  {'title': 'Senior Python Engineer in Fintech',
#   'company': 'Flowcast Inc.',
#   'location': 'No office location',
#   'link': 'https://stackoverflow.com/jobs/334701'},
#  {'title': 'PreSales Engineer / Solutions Specialist',
#   'company': 'Flowcast Inc.',
#   'location': 'Singapore',
#   'link': 'https://stackoverflow.com/jobs/333722'},
#  {'title': 'Data Engineer in Fintech',
#   'company': 'Flowcast Inc.',
#   'location': 'San Francisco CA',
#   'link': 'https://stackoverflow.com/jobs/333598'},
#  {'title': 'Test Automation Engineer in Fintech',
#   'company': 'Flowcast Inc.',
#   'location': 'San Francisco CA',
#   'link': 'https://stackoverflow.com/jobs/358279'},
#  {'title': 'Manager, Edge Performance Optimization Engineering',
#   'company': 'Facebook',
#   'location': 'Menlo Park CA',
#   'link': 'https://stackoverflow.com/jobs/370830'},
#  {'title': 'Senior Software Engineer',
#   'company': 'QuintoAndar',
#   'location': 'Vila Madalena Brazil',
#   'link': 'https://stackoverflow.com/jobs/379295'}]

# %%
# stackoverflow의 페이지를 먼저 가져오기
pagenation = soup.select('div.s-pagination')

print (pagenation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9dcadca4a13a> in <module>
#       1 # stackoverflow의 페이지를 먼저 가져오기
# ----> 2 pagenation = soup.select('div.s-pagination')
#       3
#       4 print (pagenation)
#
# NameError: name 'soup' is not defined
